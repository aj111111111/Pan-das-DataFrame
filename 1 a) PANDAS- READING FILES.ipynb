# %% [markdown]
# # Reading Files

# %%
import pandas as pd

# %%
df = pd.read_csv(r"countries of the world.csv")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# ..               ...                                  ...
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
#df = pd.read_csv(r"C:\Users\alexf\OneDrive\Documents\Pandas Tutorial\countries of the world.txt", sep = '\t')
#df

df = pd.read_table(r"countries of the world.csv", sep = ',')
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# ..               ...                                  ...
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df = pd.read_json(r"json_sample.json")
df
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  ...  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...  ...
#
#                                   The Shape Of Water  \
# 0  {'Genre': 'Adventure', 'Gross': '$448,287', 'I...
#
#            Three Billboards Outside Ebbing, Missouri  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                            Till The End Of The World  \
# 0  {'popcornscore': -1, 'rating': 'NR', 'tomatosc...
#
#                                           Winchester
# 0  {'Genre': 'Biography', 'Gross': '$696,786', 'I...
#
# [1 rows x 38 columns]

# %%
df2 = pd.read_excel(r"world_population_excel_workbook.xlsx", sheet_name = 'Sheet1')
df2
# Out:
#      Rank CCA3         Country    Capital
# 0      36  AFG     Afghanistan      Kabul
# 1     138  ALB         Albania     Tirana
# 2      34  DZA         Algeria    Algiers
# 3     213  ASM  American Samoa  Pago Pago
# ..    ...  ...             ...        ...
# 230   172  ESH  Western Sahara  El AaiÃºn
# 231    46  YEM           Yemen      Sanaa
# 232    63  ZMB          Zambia     Lusaka
# 233    74  ZWE        Zimbabwe     Harare
#
# [234 rows x 4 columns]

# %%
pd.set_option('display.max.rows', 8)
pd.set_option('display.max.columns', 8)

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     234 non-null    int64
#  1   CCA3     234 non-null    str
#  2   Country  234 non-null    str
#  3   Capital  234 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 12.1 KB

# %%
df2
# Out:
#      Rank CCA3         Country    Capital
# 0      36  AFG     Afghanistan      Kabul
# 1     138  ALB         Albania     Tirana
# 2      34  DZA         Algeria    Algiers
# 3     213  ASM  American Samoa  Pago Pago
# ..    ...  ...             ...        ...
# 230   172  ESH  Western Sahara  El AaiÃºn
# 231    46  YEM           Yemen      Sanaa
# 232    63  ZMB          Zambia     Lusaka
# 233    74  ZWE        Zimbabwe     Harare
#
# [234 rows x 4 columns]

# %%
df2.shape
# Out:
# (234, 4)

# %%
df2.tail(10)
# Out:
#      Rank CCA3         Country       Capital
# 224    43  UZB      Uzbekistan      Tashkent
# 225   181  VUT         Vanuatu     Port-Vila
# 226   234  VAT    Vatican City  Vatican City
# 227    51  VEN       Venezuela       Caracas
# ..    ...  ...             ...           ...
# 230   172  ESH  Western Sahara     El AaiÃºn
# 231    46  YEM           Yemen         Sanaa
# 232    63  ZMB          Zambia        Lusaka
# 233    74  ZWE        Zimbabwe        Harare
#
# [10 rows x 4 columns]

# %%
df2.head(10)
# Out:
#     Rank CCA3              Country         Capital
# 0     36  AFG          Afghanistan           Kabul
# 1    138  ALB              Albania          Tirana
# 2     34  DZA              Algeria         Algiers
# 3    213  ASM       American Samoa       Pago Pago
# ..   ...  ...                  ...             ...
# 6    224  AIA             Anguilla      The Valley
# 7    201  ATG  Antigua and Barbuda  Saint Johnâ€™s
# 8     33  ARG            Argentina    Buenos Aires
# 9    140  ARM              Armenia         Yerevan
#
# [10 rows x 4 columns]

# %%
df2['Rank']
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
#       ...
# 230    172
# 231     46
# 232     63
# 233     74
# Name: Rank, Length: 234, dtype: int64

# %%
df2.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital'], dtype='str')

# %%
df2[df2['Country'] == 'Uzbekistan']         # df2['Country' is boolean indexing
# Out:
#      Rank CCA3     Country   Capital
# 224    43  UZB  Uzbekistan  Tashkent

# %%
df2.loc[df2['Country'] == 'Uzbekistan']                  # same as above
# Out:
#      Rank CCA3     Country   Capital
# 224    43  UZB  Uzbekistan  Tashkent

# %% [markdown]
# **loc** - label based indexing,
#
# **iloc** - integer based indexing

# %%
df2.iloc[224]        # iloc displaying row at index 224
# Out:
# Rank               43
# CCA3              UZB
# Country    Uzbekistan
# Capital      Tashkent
# Name: 224, dtype: object

# %%
# Filters for Uzbekistan and returns only the Capital and Rank columns
df2.loc[df2['Country'] == 'Uzbekistan', ['Capital', 'Rank']]
# Out:
#       Capital  Rank
# 224  Tashkent    43
