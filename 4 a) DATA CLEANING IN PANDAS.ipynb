# %% [markdown]
# # Cleaning Data in Pandas

# %%
import pandas as pd

# %%
df = pd.read_excel(r"Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop(columns = "Not_Useful_Column")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
#df["Last_Name"] = df["Last_Name"].str.lstrip("...")
#df["Last_Name"] = df["Last_Name"].str.lstrip("/")
#df["Last_Name"] = df["Last_Name"].str.rstrip("_")
#df["Last_Name"] = df["Last_Name"].str.strip("123._/")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].astype(str).str.strip()

df["Phone_Number"] = df["Phone_Number"].str.replace(r'\D+', '', regex=True)

df["Phone_Number"] = df["Phone_Number"].replace(r'^\s*$', np.nan, regex=True)
df


# ^: The start anchor. It forces the match to look at the very beginning of the string.

# \s: Matches any whitespace character (spaces, tabs \t, or newlines \n).

# *: A quantifier meaning "zero or more times". Combined with \s, it means "allow any number of spaces (including none at all)".

# $: The end anchor. It forces the match to look at the very end of the string.

# \D: Matches any character that is not a digit (the uppercase D is the exact opposite of lowercase \d, which matches digits 0-9). It captures letters, spaces, punctuation, symbols, and dashes.

# +: A quantifier meaning "one or more times". It tells regex to grab consecutive non-digit characters as a single block rather than one by one.
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 2         1003     Walter       /White   7066950392
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 6         1007       Jeff       Winger          NaN
# 7         1008   Sherlock       Holmes   8766783469
# 8         1009    Gandalf          NaN          NaN
# 9         1010      Peter       Parker   1235455421
# 10        1011    Samwise       Gamgee          NaN
# 11        1012      Harry    ...Potter   7066950392
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace(r'(\d{3})(\d{3})(\d{4})', r'\1-\2-\3', regex=True)
df                     # made number like 123-456-789
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 2         1003     Walter       /White  706-695-0392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf          NaN           NaN
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter  706-695-0392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# ...

# %%
df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',', n=2, expand=True)
df
# ',': The delimiter (character) where the split happens.

# 2: The n parameter, which limits the maximum number of splits to 2. This 
# ensures the address is cut into a maximum of 3 parts (even if there are more commas), keeping the remaining address text intact inside the first column.

# expand=True: Forces pandas to return a DataFrame containing separate columns 
# instead of a single column containing lists.

# df[["Street_Address", "State", "Zip_Code"]] = ...: Assigns those newly
# generated columns directly back into your original DataFrame df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 2         1003     Walter       /White  706-695-0392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf          NaN           NaN
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter  706-695-0392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes','Y')

df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No','N')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 2         1003     Walter       /White  706-695-0392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf          NaN           NaN
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter  706-695-0392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# ...

# %%
#df = df.replace('N/a','')
#df = df.replace('NaN','')

df=df.fillna('')  ## This code replaces all missing or null values 
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 2         1003     Walter       /White  706-695-0392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter  706-695-0392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# 17        1018      Clark         Kent  706-695-0392
# ...

# %%
df = df.drop(df[df["Do_Not_Contact"] == 'Y'].index)
df

# df["Do_Not_Contact"] == 'Y': Creates a boolean mask (True/False for every row) checking which entries equal 'Y'.

# df[df["Do_Not_Contact"] == 'Y']: Filters the DataFrame to isolate only those matching rows.

# .index: Extracts the row index labels of those specific rows.

# df.drop(...): Removes those index labels from the original DataFrame, leaving behind only the rows where the value is not 'Y'
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 2         1003     Walter       /White  706-695-0392
# 4         1005        Jon         Snow  876-678-3469
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter  706-695-0392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# 17        1018      Clark         Kent  706-695-0392
# 19        1020     Anakin    Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# ...

# %%
df = df.drop(df[df["Do_Not_Contact"] == ''].index)  
# dropping if "Do_Not_Contact" is empty.
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 2         1005        Jon         Snow  876-678-3469
# 3         1007       Jeff       Winger
# 4         1008   Sherlock       Holmes  876-678-3469
# 6         1010      Peter       Parker  123-545-5421
# 7         1011    Samwise       Gamgee
# 9         1013        Don       Draper  123-543-2345
# 10        1014     Leslie        Knope  876-678-3469
# 11        1015       Toby  Flenderson_  304-762-2467
# 12        1016        Ron      Weasley  123-545-5421
# 13        1017   Michael         Scott  123-643-9775
# 15        1020     Anakin    Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire             Yes              N
# 2                 123 Dragons Road               Y              N
# 3                1209 South Street              No              N
# ...

# %%
df = df.reset_index(drop=True)  
#resetting index, unorganized old index, making new sequentialindex in order
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1005        Jon         Snow  876-678-3469
# 2         1007       Jeff       Winger
# 3         1008   Sherlock       Holmes  876-678-3469
# 4         1010      Peter       Parker  123-545-5421
# 5         1011    Samwise       Gamgee
# 6         1013        Don       Draper  123-543-2345
# 7         1014     Leslie        Knope  876-678-3469
# 8         1015       Toby  Flenderson_  304-762-2467
# 9         1016        Ron      Weasley  123-545-5421
# 10        1017   Michael         Scott  123-643-9775
# 11        1020     Anakin    Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire             Yes              N
# 1                 123 Dragons Road               Y              N
# 2                1209 South Street              No              N
# ...
